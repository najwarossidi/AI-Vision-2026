# %%
name = "KV-TRON"
age = 5
height = 1.75
active = True

# %%
name = "Ali"
age = 20
height = 3.8
active = True
print (name)
# Out:
# Ali

# %%
print ("hello world") #untuk baca arahan
print ("Hi geng, lope yu")
# Out:
# hello world
# Hi geng, lope yu

# %%
print ("------------------------------------")
print ("|    SELAMAT DATANG KE KVTECH      |")
print ("------------------------------------")
print ("Sistem: memulakan konfigurasi identiti..")
# Out:
# ------------------------------------
# |    SELAMAT DATANG KE KVTECH      |
# ------------------------------------
# Sistem: memulakan konfigurasi identiti..

# %%
robot_name = "KV-TRON Demo"
robot_id = 101
battery_level = 100
is_online = True

print("Nama Robot : ", robot_name, "| type :", type(robot_name))
print("ID Robot : ", robot_id, "| type:", type(robot_id))
print("Battery : ", battery_level, "%")
print("Online : ", is_online, "| type: ", type(is_online))
# Out:
# Nama Robot :  KV-TRON Demo | type : <class 'str'>
# ID Robot :  101 | type: <class 'int'>
# Battery :  100 %
# Online :  True | type:  <class 'bool'>

# %%
name = "Adriana"
age = 20
Id_class = 101
cgpa = 4.0
passed = True

print ("Name : ", name, "| type: ", type(name))
print ("Age : ", age, "| type: ", type(age))
print ("IdClass : ", Id_class, "| type: ", type(Id_class))
print ("cgpa : ", cgpa, "| type: ", type(cgpa))
print ("Passed : ", passed, "| type: ", type(passed))
# Out:
# Name :  Adriana | type:  <class 'str'>
# Age :  20 | type:  <class 'int'>
# IdClass :  101 | type:  <class 'int'>
# cgpa :  4.0 | type:  <class 'float'>
# Passed :  True | type:  <class 'bool'>

# %%
engineer_name = input ("Masukkan nama jurutera: ")
print ("Akses diberi kepada:", engineer_name)
# Out:
# Masukkan nama jurutera: halim
# Akses diberi kepada: halim

# %%
student_name = input ("Masukkan nama pelajar: ")
print (student_name, "anda boleh keluar untuk sarapan")
# Out:
# Masukkan nama pelajar: adriana
# adriana anda boleh keluar untuk sarapan

# %% [markdown]
# 1. print () - robot mula berkomunikasi
# `print()` digunakan untuk memaparkan mesej kepada pengguna.

# %% [markdown]
# # 2. Variables dan Data Types
#
# Variable ialah ruang memori untuk menyimpan data.
#
# | Data | Contoh | Type |
# |---|---|---|
# | Nama robot | "KV-TRON Rondaan" | str |
# | ID robot | 101 | int |
# | Suhu | 28.5 | float |
# | Status online | True | bool |

# %% [markdown]
# # Cabaran ringkas: lengkapkan profil robot
# **ARAHAN** : Gantikan semua `FIX_ME` dan `none` gunakan `input()` bagi nama jurutera

# %%
# ==========================================================
# FIX ME CHALLENGE: PROFIL PERMULAAN ROBOT
# ==========================================================

robot_name = "KV-TRON Safety Patrol"          # Contoh: "KV-TRON Safety Patrol"
robot_id = 205                # Contoh: 205
battery_level = 95           # Contoh: 95
operation_mode = "Pemeriksaan Bengkal"      # Contoh: "Pemeriksaan Bengkel"
robot_location = "Bengkel TVET A"      # Contoh: "Bengkel TVET A"

# FIX ME: Tukar kepada input("Masukkan nama jurutera: ")
engineer_name = input("Masukkan nama jurutera: ")

print("\n====================================")
print("       PROFIL PERMULAAN ROBOT")
print("====================================")
print("Nama Robot    :", robot_name)
print("ID Robot      :", robot_id)
print("Bateri        :", battery_level, "%")
print("Mod Operasi   :", operation_mode)
print("Lokasi        :", robot_location)
print("Jurutera      :", engineer_name)

lengkap = (
    robot_name != "FIX_ME"
    and robot_id is not None
    and battery_level is not None
    and operation_mode != "FIX_ME"
    and robot_location != "FIX_ME"
    and engineer_name != "FIX_ME"
)

print("------------------------------------")
print("[ROBOT ONLINE] Identiti lengkap." if lengkap
      else "[BELUM LENGKAP] Baiki semua bahagian FIX ME.")
# Out:
# Masukkan nama jurutera: ahmad
#
# ====================================
#        PROFIL PERMULAAN ROBOT
# ====================================
# Nama Robot    : KV-TRON Safety Patrol
# ID Robot      : 205
# Bateri        : 95 %
# Mod Operasi   : Pemeriksaan Bengkal
# Lokasi        : Bengkel TVET A
# Jurutera      : ahmad
# ------------------------------------
# [ROBOT ONLINE] Identiti lengkap.

# %%
nama = input ("Masukkan nama anda: ")
Umur = input ("Masukkan Umur anda: ")
Program = input ("Masukkan Program anda: ")
print ("\n====================================")
print ("           MAKLUMAT PENGGUNA")
print ("====================================")
print ("Nama    :", nama)
print ("Umur    :", Umur)
print ("Program :", Program)
print ("------------------------------------")
# Out:
# Masukkan nama anda: adriana
# Masukkan Umur anda: 19
# Masukkan Program anda: dka
#
# ====================================
#            MAKLUMAT PENGGUNA
# ====================================
# Nama    : adriana
# Umur    : 19
# Program : dka
# ------------------------------------

# %%
Nama = input ("Masukkan nama anda: ")
Umur = input ("Masukkan Umur anda: ")
Program = input ("Masukkan Program Pengajian anda: ")
Semester = input ("Masukkan Semester anda: ")
NamaRobot = input ("Masukkan Nama Robot anda: ")
print ("\n====================================")
print ("    PENDAFTARAN AHLO KELAB ROBOTIK    ")
print ("======================================")
print ("Nama    :", Nama)
print ("Umur    :", Umur)
print ("Program :", Program)
print ("Semester:", Semester)
print ("Robot Pilihan:", NamaRobot)
print ("======================================")
print ("\n====================================")
print ("Jenis Data")
print ("======================================")
print ("Nama    :", type(Nama))
print ("Umur    :", type(Umur))
print ("Program :", type(Program))
print ("Semester:", type(Semester))
print ("Robot Pilihan:", type(NamaRobot))
# Out:
# Masukkan nama anda: Adriana
# Masukkan Umur anda: 19
# Masukkan Program Pengajian anda: DKA
# Masukkan Semester anda: 3
# Masukkan Nama Robot anda: kv-tron
#
# ====================================
#     PENDAFTARAN AHLO KELAB ROBOTIK
# ======================================
# Nama    : Adriana
# Umur    : 19
# Program : DKA
# Semester: 3
# Robot Pilihan: kv-tron
# ======================================
#
# ====================================
# Jenis Data
# ======================================
# Nama    : <class 'str'>
# Umur    : <class 'str'>
# Program : <class 'str'>
# Semester: <class 'str'>
# Robot Pilihan: <class 'str'>
